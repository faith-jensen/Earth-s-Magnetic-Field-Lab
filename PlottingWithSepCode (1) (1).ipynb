# %%
import physplot as phys
import numpy as np
from __future__ import division

array1 = np.array([-50, -40, -30, -20, -10, 10, 20, 30, 40, 50])
array1_rad = ((array1*np.pi)/180)
tantheta = np.tan(array1_rad)
current = np.array([-35.2, -25.8, -16.3, -10.49, -4.58, 4.08, 10.34, 16.01, 24.2, 35.7])
err_current = np.array([.2, .2, .2, .2, .2, .2, .2, .2, .2, .2])

#plotfit takes in parameters in this order
#phys.plotfit(x,y,dy,title,'xlabel(units)','ylabel(units)','slope units')  Slope units will not render in LaTeX

phys.plotfit(tantheta,current,err_current,'100 Coils','tanthetha($radians$)','current(mA)','rad/mA')
# Out:
# Slope = 29.42 rad/mA
# Error in slope = 0.09 rad/mA
# Goodness of fit = 117.21

# %%
import physplot as phys
import numpy as np
from __future__ import division

array1 = np.array([-50, -40, -30, -20, -10, 10, 20, 30, 40, 50])
array1_rad = ((array1*np.pi)/180)
tantheta = np.tan(array1_rad)
current = np.array([-17.52, -13.11, -8.09, -5.2, -2.39, 1.98, 5.22, 9.09, 12.28, 17.83])
err_current = np.array([.2, .2, .2, .2, .2, .2, .2, .2, .2, .2])

#plotfit takes in parameters in this order
#phys.plotfit(x,y,dy,title,'xlabel(units)','ylabel(units)','slope units')  Slope units will not render in LaTeX

phys.plotfit(tantheta,current,err_current,'200 Coils','tanthetha($radians$)','current(mA)','rad/mA')
# Out:
# Slope = 14.86 rad/mA
# Error in slope = 0.09 rad/mA
# Goodness of fit = 38.46

# %%
#Error of Be for 100 coils

import numpy as np

def rule4(m, dA, A, n, dB, B, Q):
    dQ = Q*np.sqrt(((m*dA)/A)**2 + ((n*dB)/B)**2)
    return dQ

m = 1
dA = .2
A = 29.42
n = 1
dB = .1
B = 10.9
Q = .00001696

dQ = rule4(m, dA, A, n, dB, B, Q)
print (dQ)
# Out:
# 1.936577403554852e-07

# %%
#Error of Be for 200 coils

import numpy as np

def rule4(m, dA, A, n, dB, B, Q):
    dQ = Q*np.sqrt(((m*dA)/A)**2 + ((n*dB)/B)**2)
    return dQ

m = 1
dA = .2
A = 14.86
n = 1
dB = .1
B = 10.9
Q = .000017131

dQ = rule4(m, dA, A, n, dB, B, Q)
print (dQ)
# Out:
# 2.7903624663508156e-07
